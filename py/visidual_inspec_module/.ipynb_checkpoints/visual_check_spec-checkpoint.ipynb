# %%
import subprocess
import os
import sys
sys.path.append('../')
import utils as ul
import copy
import pickle
import gzip
from matplotlib import pyplot as plt
import numpy as np
from scipy.signal import medfilt
import h5py
from scipy.stats import norm
import time
import pymultinest
import json
import copy

in_dir = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/'
lya_hits = pickle.load(gzip.open(in_dir+'lya_hits_cut.pzip'))

dir1 = os.getcwd()
os.chdir('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/2')
dir2 = os.getcwd()

plate_list = lya_hits['plate_hits']
fiber_list = lya_hits['fiber_hits']
mjd_list = lya_hits['mjd_hits']
spec_id_list = lya_hits['spec_id']
peak_id_list = lya_hits['peak_id']
peak_wave_list = lya_hits['peak_wave']
peak_sn_list = lya_hits['peak_sn']

t1 = time.time()
for i in range(plate_list.size):
    this_plate = plate_list[i]
    this_mjd = mjd_list[i]
    this_fiber = fiber_list[i]
    this_spec_id = spec_id_list[i]
    this_peak_id = peak_id_list[i]
    this_peak_wave = peak_wave_list[i]
    this_peak_sn = peak_sn_list[i]
    h5_file = '{}_{}.h5'.format(this_plate,this_mjd)
    with h5py.File(h5_file, 'r') as f:
        arr0 = f['flux']
        flux = arr0[:]
        
        arr1 = f['loglam']
        loglam = arr1[:]
        
        arr2 = f['zans']
        zans = arr2[:]
        
        arr3 = f['newsynflux']
        synflux = arr3[:]
        
        arr4 = f['res_ivar']
        res_ivar = arr4[:]
    
    
    this_wave = 10**loglam
    this_flux = flux[this_spec_id,:]
    this_synflux = synflux[this_spec_id,:]
    this_resflux = this_flux - this_synflux
    this_res_ivar = res_ivar[this_spec_id,:]
    this_sn = np.sqrt(this_resflux**2 * this_res_ivar)

    
    hw_sub = 50 #empirically choice
    wave_sub = this_wave[this_peak_id-hw_sub:this_peak_id+hw_sub+1]
    resflux_sub =  this_resflux[this_peak_id-hw_sub:this_peak_id+hw_sub+1]
    res_ivar_sub = this_res_ivar[this_peak_id-hw_sub:this_peak_id+hw_sub+1]
    sn_sub = this_sn[this_peak_id-hw_sub:this_peak_id+hw_sub+1]
    
    #------------------------------fitting block---------------
    #fitting x-coordinates
    npix = wave_sub.size
    wave_fit = np.arange(0,npix)
    #fitting data/uncertainty
    dlam = wave_sub * 1.0e-4 * np.log(10.0)
    obs = np.copy(resflux_sub * dlam)
    weight = np.copy(res_ivar_sub / dlam**2)
    ul.npix = np.copy(npix)
    ul.obs = np.copy(obs)
    ul.weight = np.copy(weight)
    ul.wave_fit = np.copy(wave_fit)
    
    png_name = '{}-{}-{}'.format(this_plate,this_mjd,this_fiber)
    multinest_base_dir = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/'
   
    #single peak
    if not os.path.exists(multinest_base_dir+'single/'+png_name+'_1/'):  
        multinest_output = multinest_base_dir+'single/'+png_name+'_1/'
        os.mkdir(multinest_output)
    else:
        output = subprocess.Popen('ls -d {}single/{}*'.format(multinest_base_dir, png_name),stdout=subprocess.PIPE,shell=True)
        #print('ls -d {}single/{}*'.format(multinest_base_dir, out_png))
        lines = output.stdout.read().splitlines()
        #print(lines,'>>>>')
        k_hits = len(lines)
        multinest_output = multinest_base_dir+'single/'+png_name+'_{}/'.format(k_hits+1)
        os.mkdir(multinest_output)
    parameters = ['A', 'x', 'omega', 's']
    n_params = len(parameters)
    pymultinest.run(ul.loglike_single, ul.prior_single, n_params, resume =False, verbose = True,outputfiles_basename=multinest_output,
                   n_live_points=300, evidence_tolerance=0.5,sampling_efficiency=0.05,
                   importance_nested_sampling=False,const_efficiency_mode=True, multimodal=True)
    json.dump(parameters, open(multinest_output+'params.json', 'w'))
    res = pymultinest.Analyzer(outputfiles_basename=multinest_output, n_params = n_params)
    xx = res.get_best_fit()
    #print(xx)
    like_single = xx['log_likelihood']
    ev_single = res.get_stats()['global evidence']
    print('evidence value:',ev_single)
    fit_par_single = xx['parameters']
    #plt.figure()
    #plt.bar(wave_fit,obs,alpha=0.5,width=1)
    #plt.plot(wave_fit,ul.skew_gauss(npix , *fit_par,hw_sub=10),color='red')
    #plt.show()
    
    #double peak
    if not os.path.exists(multinest_base_dir+'double/'+png_name+'_1/'):  
        multinest_output = multinest_base_dir+'double/'+png_name+'_1/'
        os.mkdir(multinest_output)
    else:
        output = subprocess.Popen('ls -d {}double/{}*'.format(multinest_base_dir, png_name),stdout=subprocess.PIPE,shell=True)
        lines = output.stdout.read().splitlines()
        k_hits = len(lines)
        multinest_output = multinest_base_dir+'double/'+png_name+'_{}/'.format(k_hits+1)
        os.mkdir(multinest_output)
    parameters = ['flux_ratio', 'offset', 'omega1', 's1', 'A2', 'x2', 'omega2', 's2']
    n_params = len(parameters)
    pymultinest.run(ul.loglike_double, ul.prior_double, n_params, resume =False, verbose = True,outputfiles_basename=multinest_output,
                   n_live_points=300, evidence_tolerance=0.5,sampling_efficiency=0.05,
                   importance_nested_sampling=False,const_efficiency_mode=True, multimodal=True)
    json.dump(parameters, open(multinest_output+'params.json', 'w'))
    res = pymultinest.Analyzer(outputfiles_basename=multinest_output, n_params = n_params)
    xx = res.get_best_fit()
    #print(xx)
    like_double = xx['log_likelihood']
    ev_double = res.get_stats()['global evidence']
    print('evidence value:',ev_double)
    fit_par_double = xx['parameters']
    #plt.figure()
    #plt.bar(wave_fit,obs,alpha=0.5,width=1)
    #plt.plot(wave_fit,ul.double_peak(npix , *fit_par,hw_sub=10),color='red')
    #plt.show()
    #------------------------------fitting block---------------
    
    #make sure reading process is correct
    #print(zans[this_spec_id])
    #print(this_plate,this_mjd,this_fiber)
    
    #visulization
    import matplotlib.gridspec as gridspec
    name = r'ID: {}-{}-{}'.format(this_plate,this_mjd,this_fiber)
    hit_wave = r'Hit $\lambda$: {:.2f}'.format(this_peak_wave)
    hit_sn = r'Hit SN: {:.2f}'.format(this_peak_sn)
    textstr = '\n'.join((name,hit_wave,hit_sn))
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    
    #fig, ax = plt.subplots(2,2,figsize=(20,15)) #,sharey=True
    fig = plt.figure(figsize=(50,30),tight_layout=True)
    gs = gridspec.GridSpec(3, 5)
    
    #--------------------------subplot 0,0:
    ax = fig.add_subplot(gs[0, :])
    ax.plot(this_wave,this_flux,color='deepskyblue')
    ax.plot(this_wave, this_synflux,color='red')
    ax.axvline(x=this_peak_wave,color='magenta')
    id_mask = ul.return_mask_region_id(this_res_ivar)
    for this_mask_id in id_mask:
        low = this_mask_id[0]
        high = this_mask_id[1]
        #print(this_wave[low],this_wave[high-1])
        ax.axvspan(this_wave[low], this_wave[high-1], facecolor='g', alpha=0.5)
    #ax[0,0].set_xlim(3700,4800)
    up_lim = this_flux.max()*1.2
    if this_flux.min() < 0:
        low_lim = this_flux.min()*1.2
    else:
        low_lim = -0.1
    ax.set_ylim(low_lim,up_lim)
    
    
    #--------------------------subplot 1,1
    ax = fig.add_subplot(gs[1, 1:])
    ax.plot(this_wave,this_flux,color='deepskyblue')
    ax.plot(this_wave, this_synflux,color='red')
    ax.axvline(x=this_peak_wave,color='magenta')
    id_mask = ul.return_mask_region_id(this_res_ivar)
    for this_mask_id in id_mask:
        low = this_mask_id[0]
        high = this_mask_id[1]
        #print(this_wave[low],this_wave[high-1])
        ax.axvspan(this_wave[low], this_wave[high-1], facecolor='g', alpha=0.5)
    ax.set_xlim(3700,4800)
    id_tmp = np.where(np.logical_and(this_wave<4800,this_wave>3700))
    up_lim = this_flux[id_tmp].max()*1.2
    if this_flux[id_tmp].min() < 0:
        low_lim = this_flux[id_tmp].min()*1.2
    else:
        low_lim = -0.1
    ax.set_ylim(low_lim,up_lim)
    
    
    #--------------------------subplot 2,0
    ax = fig.add_subplot(gs[2, 0])
    ax.bar(wave_sub,sn_sub,alpha=0.5)
    ax.plot(wave_sub,sn_sub,color='red')
    ax.axvline(x=this_peak_wave,color='magenta')
    ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=10,
            verticalalignment='top', bbox=props)
    wave_, sn_ = ul.return_peak(wave_sub,sn_sub)
    ax.plot(wave_,sn_,'*',color='black',ms=20)
    
    
    #--------------------------subplot 2,1
    ax = fig.add_subplot(gs[2, 1])
    _,sn_filter_0,_ = ul.filter_sn(resflux=resflux_sub,resivar=res_ivar_sub,wave=wave_sub,pix_sigma=1.1,kern_size=15)
    ax.bar(wave_sub,sn_filter_0,alpha=0.5)
    ax.plot(wave_sub,sn_filter_0,color='red')
    ax.axvline(x=this_peak_wave,color='magenta')
    ax.text(0.05, 0.95, 'filtered spectrum 1.1', transform=ax.transAxes, fontsize=15,
            verticalalignment='top', bbox=props)
    wave_, sn_ = ul.return_peak(wave_sub,sn_filter_0)
    ax.plot(wave_, sn_,'*',color='black',ms=20)
    
    
    #--------------------------subplot 2,2
    ax = fig.add_subplot(gs[2, 2])
    _,sn_filter_1,_ = ul.filter_sn(resflux=resflux_sub,resivar=res_ivar_sub,wave=wave_sub,pix_sigma=2.2,kern_size=15)
    ax.bar(wave_sub,sn_filter_1,alpha=0.5)
    ax.plot(wave_sub,sn_filter_1,color='red')
    ax.axvline(x=this_peak_wave,color='magenta')
    ax.text(0.05, 0.95, 'filtered spectrum 2.2', transform=ax.transAxes, fontsize=15,
            verticalalignment='top', bbox=props)
    wave_, sn_ = ul.return_peak(wave_sub,sn_filter_1)
    ax.plot(wave_, sn_,'*',color='black',ms=20)
    
    #--------------------------subplot 2,3
    ax = fig.add_subplot(gs[2, 3])
    ax.bar(wave_fit,obs,alpha=0.5,width=1)
    ax.plot(wave_fit,ul.skew_gauss(npix , *fit_par_single,hw_sub=2),color='red')
    ax.text(0.05, 0.95, 'Ev: {}\nLike: {}'.format(ev_single,like_single), transform=ax.transAxes, fontsize=15,
            verticalalignment='top', bbox=props)
    

    #--------------------------subplot 2,4
    ax = fig.add_subplot(gs[2, 4])
    ax.bar(wave_fit,obs,alpha=0.5,width=1)
    ax.plot(wave_fit,ul.double_peak(npix , *fit_par_double,hw_sub=2),color='red')
    ax.text(0.05, 0.95, 'Ev: {}\nLike: {}'.format(ev_double,like_double), transform=ax.transAxes, fontsize=15,
            verticalalignment='top', bbox=props)
    
    #--------------------------subplot 1,0
    data_dir = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/cross_talk/'
    color = ['black','red','cyan']
    ax = fig.add_subplot(gs[1, 0])
    for jj in range(3):
        h5_file = data_dir + '{}_{}_{}_{}.h5'.format(this_plate,this_mjd, this_fiber,jj)
        with h5py.File(h5_file, 'r') as f:
            arr0 = f['flux']
            flux = arr0[:]
            
            arr1 = f['wave']
            wave = arr1[:]
            
            arr2 = f['zans']
            zans = arr2[:]
        ax.plot(wave,flux,color=color[jj])
        ax.set_xlim(this_peak_wave-50,this_peak_wave+50)
        ax.minorticks_on()
    
    #plt.show()
    #png_name = '{}-{}-{}'.format(this_plate,this_mjd,this_fiber)
    out_png = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/{}'.format(png_name)
    if not os.path.exists(out_png+'_1.png'):  
        fig.savefig(out_png+'_1.png',dpi=40,bbox_inches='tight')
        plt.close(fig)
        print(out_png+'_1.png','---{} image-----finished!'.format(i))
    else:
        output = subprocess.Popen('ls -d {}*'.format(out_png),stdout=subprocess.PIPE,shell=True)
        lines = output.stdout.read().splitlines()
        print('----lines:',lines)
        k_hits = len(lines)
        fig.savefig(out_png+'_{}.png'.format(k_hits+1),dpi=50,bbox_inches='tight')
        plt.close(fig)
        print(out_png+'_{}.png'.format(k_hits+1),'---{} image-----finished!'.format(i),'!!!!!!')
t2 = time.time()
print('total time elapse:',t2-t1)
# Out:
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10243-58159-381_1/.txt
# ('evidence value:', -56.36499079665449)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10243-58159-381_1/.txt
# ('evidence value:', -61.64603285107123)
# /data/inspur_disk03/userdir/caoxy/software/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10243-58159-381_1.png', '---0 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10272-58172-937_1/.txt
# ('evidence value:', -73.27241611161709)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10272-58172-937_1/.txt
# ('evidence value:', -75.23597680812485)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10272-58172-937_1.png', '---1 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10274-58170-211_1/.txt
# ('evidence value:', -49.34726255378325)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10274-58170-211_1/.txt
# ('evidence value:', -52.49926446802945)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10274-58170-211_1.png', '---2 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10287-58101-813_1/.txt
# ('evidence value:', -61.17823998132129)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10287-58101-813_1/.txt
# ('evidence value:', -61.98463076550949)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10287-58101-813_1.png', '---3 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10429-58145-395_1/.txt
# ('evidence value:', -91.52688619979787)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10429-58145-395_1/.txt
# ('evidence value:', -93.97938374082072)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10429-58145-395_1.png', '---4 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10431-58137-159_1/.txt
# ('evidence value:', -74.3294077127347)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10431-58137-159_1/.txt
# ('evidence value:', -79.27542166475449)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10431-58137-159_1.png', '---5 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10431-58137-392_1/.txt
# ('evidence value:', -93.50744028043148)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10431-58137-392_1/.txt
# ('evidence value:', -88.91346131758196)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10431-58137-392_1.png', '---6 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10431-58137-392_2/.txt
# ('evidence value:', -62.9468090984945)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10431-58137-392_2/.txt
# ('evidence value:', -63.45403969351326)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10431-58137-392_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10431-58137-392_2.png', '---7 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10435-58156-475_1/.txt
# ('evidence value:', -67.60832096685931)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10435-58156-475_1/.txt
# ('evidence value:', -71.44928917293998)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10435-58156-475_1.png', '---8 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10441-58138-465_1/.txt
# ('evidence value:', -116.46603516899316)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10441-58138-465_1/.txt
# ('evidence value:', -126.39947371011755)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10441-58138-465_1.png', '---9 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10446-58133-607_1/.txt
# ('evidence value:', -58.2210585044013)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10446-58133-607_1/.txt
# ('evidence value:', -63.25342054039851)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10446-58133-607_1.png', '---10 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10449-58137-465_1/.txt
# ('evidence value:', -115.65415386792726)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10449-58137-465_1/.txt
# ('evidence value:', -120.8370157594983)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10449-58137-465_1.png', '---11 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10452-58138-812_1/.txt
# ('evidence value:', -167.3743734461261)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10452-58138-812_1/.txt
# ('evidence value:', -172.84229104877144)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10452-58138-812_1.png', '---12 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10454-58135-354_1/.txt
# ('evidence value:', -68.11107418846261)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10454-58135-354_1/.txt
# ('evidence value:', -65.26405826660547)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10454-58135-354_1.png', '---13 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10455-58158-164_1/.txt
# ('evidence value:', -45.74831527442091)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10455-58158-164_1/.txt
# ('evidence value:', -46.67810163546002)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10455-58158-164_1.png', '---14 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10455-58158-730_1/.txt
# ('evidence value:', -50.729143142719956)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10455-58158-730_1/.txt
# ('evidence value:', -50.45665588724629)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10455-58158-730_1.png', '---15 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10459-58159-789_1/.txt
# ('evidence value:', -61.44905446327835)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10459-58159-789_1/.txt
# ('evidence value:', -59.29569313588083)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10459-58159-789_1.png', '---16 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10469-58133-381_1/.txt
# ('evidence value:', -73.96950387710706)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10469-58133-381_1/.txt
# ('evidence value:', -78.32840186948532)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10469-58133-381_1.png', '---17 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10470-58130-253_1/.txt
# ('evidence value:', -45.82482027601417)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10470-58130-253_1/.txt
# ('evidence value:', -47.827929232369485)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10470-58130-253_1.png', '---18 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10474-58143-579_1/.txt
# ('evidence value:', -44.570056815201085)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10474-58143-579_1/.txt
# ('evidence value:', -45.59987063426446)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10474-58143-579_1.png', '---19 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10475-58137-286_1/.txt
# ('evidence value:', -119.80641363483466)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10475-58137-286_1/.txt
# ('evidence value:', -128.03396399654082)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10475-58137-286_1.png', '---20 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10666-58440-791_1/.txt
# ('evidence value:', -57.48658519768576)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10666-58440-791_1/.txt
# ('evidence value:', -58.847406156336525)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10666-58440-791_1.png', '---21 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10723-58287-211_1/.txt
# ('evidence value:', -46.61458615649138)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10723-58287-211_1/.txt
# ('evidence value:', -48.70177747594895)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10723-58287-211_1.png', '---22 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10730-58244-395_1/.txt
# ('evidence value:', -88.82556357183375)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10730-58244-395_1/.txt
# ('evidence value:', -90.80889290759319)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10730-58244-395_1.png', '---23 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10730-58244-609_1/.txt
# ('evidence value:', -45.74120874698651)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10730-58244-609_1/.txt
# ('evidence value:', -48.08122177387179)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10730-58244-609_1.png', '---24 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10732-58253-657_1/.txt
# ('evidence value:', -47.85391628454155)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10732-58253-657_1/.txt
# ('evidence value:', -49.36781737604302)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10732-58253-657_1.png', '---25 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10735-58258-381_1/.txt
# ('evidence value:', -55.738130143180484)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10735-58258-381_1/.txt
# ('evidence value:', -58.886648465238444)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10735-58258-381_1.png', '---26 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10740-58223-219_1/.txt
# ('evidence value:', -61.94004735037732)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10740-58223-219_1/.txt
# ('evidence value:', -64.27295398600366)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10740-58223-219_1.png', '---27 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10740-58223-643_1/.txt
# ('evidence value:', -52.695273198588424)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10740-58223-643_1/.txt
# ('evidence value:', -52.714460282265044)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10740-58223-643_1.png', '---28 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10745-58277-87_1/.txt
# ('evidence value:', -105.74458196905245)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10745-58277-87_1/.txt
# ('evidence value:', -102.44950207659647)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10745-58277-87_1.png', '---29 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10748-58224-395_1/.txt
# ('evidence value:', -51.794862779995455)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10748-58224-395_1/.txt
# ('evidence value:', -54.263458250511505)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10748-58224-395_1.png', '---30 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10751-58220-189_1/.txt
# ('evidence value:', -69.85384111472189)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10751-58220-189_1/.txt
# ('evidence value:', -59.41964374444864)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10751-58220-189_1.png', '---31 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10752-58488-809_1/.txt
# ('evidence value:', -52.38863097069156)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10752-58488-809_1/.txt
# ('evidence value:', -56.60489602044782)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10752-58488-809_1.png', '---32 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10753-58242-289_1/.txt
# ('evidence value:', -62.964820064330794)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10753-58242-289_1/.txt
# ('evidence value:', -61.926259792323386)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10753-58242-289_1.png', '---33 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10754-58224-475_1/.txt
# ('evidence value:', -55.638282716686604)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10754-58224-475_1/.txt
# ('evidence value:', -58.29266418121996)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10754-58224-475_1.png', '---34 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/10921-58251-715_1/.txt
# ('evidence value:', -47.24383646863808)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/10921-58251-715_1/.txt
# ('evidence value:', -48.056846459419276)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/10921-58251-715_1.png', '---35 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11045-58485-393_1/.txt
# ('evidence value:', -59.13313557871352)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11045-58485-393_1/.txt
# ('evidence value:', -59.65470271518188)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11045-58485-393_1.png', '---36 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11055-58429-325_1/.txt
# ('evidence value:', -58.87439697136335)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11055-58429-325_1/.txt
# ('evidence value:', -60.84020095590829)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11055-58429-325_1.png', '---37 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11096-58485-519_1/.txt
# ('evidence value:', -65.03364630762329)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11096-58485-519_1/.txt
# ('evidence value:', -66.19425264950307)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11096-58485-519_1.png', '---38 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11123-58429-77_1/.txt
# ('evidence value:', -53.203260524528126)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11123-58429-77_1/.txt
# ('evidence value:', -54.9723825150141)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11123-58429-77_1.png', '---39 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11316-58396-95_1/.txt
# ('evidence value:', -53.69503222657667)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11316-58396-95_1/.txt
# ('evidence value:', -51.73371873581743)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11316-58396-95_1.png', '---40 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11341-58428-83_1/.txt
# ('evidence value:', -46.02636120495173)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11341-58428-83_1/.txt
# ('evidence value:', -47.7877323767658)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11341-58428-83_1.png', '---41 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11345-58428-231_1/.txt
# ('evidence value:', -52.00355285837237)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11345-58428-231_1/.txt
# ('evidence value:', -51.396314357026306)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11345-58428-231_1.png', '---42 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11351-58440-437_1/.txt
# ('evidence value:', -61.26610637412946)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11351-58440-437_1/.txt
# ('evidence value:', -62.3960147442563)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11351-58440-437_1.png', '---43 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11388-58487-171_1/.txt
# ('evidence value:', -42.26370632040196)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11388-58487-171_1/.txt
# ('evidence value:', -44.187446982025314)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11388-58487-171_1.png', '---44 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11391-58526-383_1/.txt
# ('evidence value:', -70.16291219688594)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11391-58526-383_1/.txt
# ('evidence value:', -71.04303474674131)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11391-58526-383_1.png', '---45 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11554-58456-287_1/.txt
# ('evidence value:', -77.14867467843663)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11554-58456-287_1/.txt
# ('evidence value:', -78.6702303810909)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11554-58456-287_1.png', '---46 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11554-58456-901_1/.txt
# ('evidence value:', -58.67527824788619)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11554-58456-901_1/.txt
# ('evidence value:', -58.93183397855356)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11554-58456-901_1.png', '---47 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11675-58523-399_1/.txt
# ('evidence value:', -50.18135588563518)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11675-58523-399_1/.txt
# ('evidence value:', -50.8015548265807)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11675-58523-399_1.png', '---48 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/11676-58512-157_1/.txt
# ('evidence value:', -53.90817244121791)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/11676-58512-157_1/.txt
# ('evidence value:', -54.97010620867068)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/11676-58512-157_1.png', '---49 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3588-55184-458_1/.txt
# ('evidence value:', -29.96025413012263)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3588-55184-458_1/.txt
# ('evidence value:', -27.9519626633514)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3588-55184-458_1.png', '---50 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3589-55186-713_1/.txt
# ('evidence value:', -60.8767322880249)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3589-55186-713_1/.txt
# ('evidence value:', -54.67870965546248)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3589-55186-713_1.png', '---51 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3590-55201-629_1/.txt
# ('evidence value:', -63.92181305390422)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3590-55201-629_1/.txt
# ('evidence value:', -64.34880805234265)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3590-55201-629_1.png', '---52 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3590-55201-741_1/.txt
# ('evidence value:', -54.324151232382185)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3590-55201-741_1/.txt
# ('evidence value:', -54.03586423552931)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3590-55201-741_1.png', '---53 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3606-55182-695_1/.txt
# ('evidence value:', -49.47612464970282)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3606-55182-695_1/.txt
# ('evidence value:', -46.34056394963022)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3606-55182-695_1.png', '---54 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3615-55179-155_1/.txt
# ('evidence value:', -85.70458466910974)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3615-55179-155_1/.txt
# ('evidence value:', -64.74365841259332)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3615-55179-155_1.png', '---55 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3615-56544-27_1/.txt
# ('evidence value:', -125.7857541435316)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3615-56544-27_1/.txt
# ('evidence value:', -128.5925780737631)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3615-56544-27_1.png', '---56 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3639-55205-743_1/.txt
# ('evidence value:', -63.25389566469437)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3639-55205-743_1/.txt
# ('evidence value:', -64.44448011614203)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3639-55205-743_1.png', '---57 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3639-55205-877_1/.txt
# ('evidence value:', -59.33286087766636)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3639-55205-877_1/.txt
# ('evidence value:', -60.999211911990066)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3639-55205-877_1.png', '---58 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3647-55241-157_1/.txt
# ('evidence value:', -69.6022926250632)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3647-55241-157_1/.txt
# ('evidence value:', -60.21239593833742)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3647-55241-157_1.png', '---59 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3647-55476-785_1/.txt
# ('evidence value:', -56.013429414138244)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3647-55476-785_1/.txt
# ('evidence value:', -56.346541549079056)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3647-55476-785_1.png', '---60 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3647-56219-802_1/.txt
# ('evidence value:', -44.23828317763189)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3647-56219-802_1/.txt
# ('evidence value:', -45.171758027109036)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3647-56219-802_1.png', '---61 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3655-55240-517_1/.txt
# ('evidence value:', -75.20304073430164)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3655-55240-517_1/.txt
# ('evidence value:', -52.05120953686884)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_1.png', '---62 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3655-55240-517_2/.txt
# ('evidence value:', -92.74004240942106)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3655-55240-517_2/.txt
# ('evidence value:', -52.9190191017679)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_2.png', '---63 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3655-55240-517_3/.txt
# ('evidence value:', -76.65050251475145)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3655-55240-517_3/.txt
# ('evidence value:', -57.122792355610386)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_1.png', '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_2.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3655-55240-517_3.png', '---64 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3656-55241-799_1/.txt
# ('evidence value:', -75.5682239407537)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3656-55241-799_1/.txt
# ('evidence value:', -58.24193919300355)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3656-55241-799_1.png', '---65 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3660-55209-857_1/.txt
# ('evidence value:', -71.67294595649582)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3660-55209-857_1/.txt
# ('evidence value:', -64.58053658003827)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3660-55209-857_1.png', '---66 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3667-55566-270_1/.txt
# ('evidence value:', -33.99817569703932)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3667-55566-270_1/.txt
# ('evidence value:', -35.02496560173853)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3667-55566-270_1.png', '---67 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-7_1/.txt
# ('evidence value:', -73.50075330158725)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-7_1/.txt
# ('evidence value:', -48.094327700074)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_1.png', '---68 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-7_2/.txt
# ('evidence value:', -80.56502463625878)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-7_2/.txt
# ('evidence value:', -53.60133209840938)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_2.png', '---69 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-7_3/.txt
# ('evidence value:', -75.65837023214081)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-7_3/.txt
# ('evidence value:', -61.839322705963845)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_1.png', '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_2.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-7_3.png', '---70 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-573_1/.txt
# ('evidence value:', -98.34500723282893)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-573_1/.txt
# ('evidence value:', -61.347767934604775)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_1.png', '---71 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-573_2/.txt
# ('evidence value:', -101.31206793258355)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-573_2/.txt
# ('evidence value:', -62.99007037105299)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_2.png', '---72 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3669-55481-573_3/.txt
# ('evidence value:', -67.0263587420776)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3669-55481-573_3/.txt
# ('evidence value:', -54.87240079711435)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_1.png', '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_2.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3669-55481-573_3.png', '---73 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3670-55480-599_1/.txt
# ('evidence value:', -89.77163169370881)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3670-55480-599_1/.txt
# ('evidence value:', -89.86288907737612)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3670-55480-599_1.png', '---74 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3673-55178-205_1/.txt
# ('evidence value:', -70.2974252326808)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3673-55178-205_1/.txt
# ('evidence value:', -71.46587354867266)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3673-55178-205_1.png', '---75 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3673-55178-336_1/.txt
# ('evidence value:', -47.36577751585822)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3673-55178-336_1/.txt
# ('evidence value:', -46.13228037998004)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3673-55178-336_1.png', '---76 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3673-55178-351_1/.txt
# ('evidence value:', -58.87178795640836)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3673-55178-351_1/.txt
# ('evidence value:', -59.30104590223573)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3673-55178-351_1.png', '---77 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3673-55178-795_1/.txt
# ('evidence value:', -60.739034788319614)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3673-55178-795_1/.txt
# ('evidence value:', -62.80773930335068)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3673-55178-795_1.png', '---78 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3676-55186-623_1/.txt
# ('evidence value:', -66.06515183367816)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3676-55186-623_1/.txt
# ('evidence value:', -67.01273978096843)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3676-55186-623_1.png', '---79 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3680-55210-295_1/.txt
# ('evidence value:', -94.09547410096144)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3680-55210-295_1/.txt
# ('evidence value:', -87.35561918195158)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3680-55210-295_1.png', '---80 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3680-55210-295_2/.txt
# ('evidence value:', -76.47459417107031)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3680-55210-295_2/.txt
# ('evidence value:', -71.26248180468232)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3680-55210-295_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3680-55210-295_2.png', '---81 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3681-55243-626_1/.txt
# ('evidence value:', -38.42077673220392)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3681-55243-626_1/.txt
# ('evidence value:', -43.291345587803036)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3681-55243-626_1.png', '---82 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3681-55243-651_1/.txt
# ('evidence value:', -70.0226709522263)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3681-55243-651_1/.txt
# ('evidence value:', -71.39669309492159)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3681-55243-651_1.png', '---83 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3681-55243-721_1/.txt
# ('evidence value:', -75.42885375049065)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3681-55243-721_1/.txt
# ('evidence value:', -75.46988825601352)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3681-55243-721_1.png', '---84 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3681-55243-721_2/.txt
# ('evidence value:', -80.68732896093756)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3681-55243-721_2/.txt
# ('evidence value:', -80.24792551906445)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3681-55243-721_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3681-55243-721_2.png', '---85 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3682-55244-681_1/.txt
# ('evidence value:', -76.30723494820101)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3682-55244-681_1/.txt
# ('evidence value:', -79.00941501656844)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3682-55244-681_1.png', '---86 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3682-55244-681_2/.txt
# ('evidence value:', -71.5147980421646)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3682-55244-681_2/.txt
# ('evidence value:', -73.25198335500313)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3682-55244-681_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3682-55244-681_2.png', '---87 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3683-55178-662_1/.txt
# ('evidence value:', -64.63769633778959)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3683-55178-662_1/.txt
# ('evidence value:', -64.17443535665542)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3683-55178-662_1.png', '---88 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3683-55245-671_1/.txt
# ('evidence value:', -52.22753336876308)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3683-55245-671_1/.txt
# ('evidence value:', -53.53560027417676)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3683-55245-671_1.png', '---89 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3687-55269-346_1/.txt
# ('evidence value:', -63.62471692825796)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3687-55269-346_1/.txt
# ('evidence value:', -57.639916343556465)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3687-55269-346_1.png', '---90 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3688-55273-661_1/.txt
# ('evidence value:', -34.169063841296115)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3688-55273-661_1/.txt
# ('evidence value:', -34.184635652484154)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3688-55273-661_1.png', '---91 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3689-55180-15_1/.txt
# ('evidence value:', -62.82380110523786)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3689-55180-15_1/.txt
# ('evidence value:', -63.71262793034368)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3689-55180-15_1.png', '---92 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3690-55182-643_1/.txt
# ('evidence value:', -59.00085190495971)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3690-55182-643_1/.txt
# ('evidence value:', -60.84398498109453)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3690-55182-643_1.png', '---93 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3690-55182-885_1/.txt
# ('evidence value:', -43.61583249031912)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3690-55182-885_1/.txt
# ('evidence value:', -41.890942864022065)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3690-55182-885_1.png', '---94 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3691-55274-138_1/.txt
# ('evidence value:', -65.75484069078031)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3691-55274-138_1/.txt
# ('evidence value:', -64.31739350927316)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3691-55274-138_1.png', '---95 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3693-55208-119_1/.txt
# ('evidence value:', -49.889196267692334)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3693-55208-119_1/.txt
# ('evidence value:', -46.54993645252836)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3693-55208-119_1.png', '---96 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3694-55209-723_1/.txt
# ('evidence value:', -47.40923039052307)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3694-55209-723_1/.txt
# ('evidence value:', -48.775365690426725)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3694-55209-723_1.png', '---97 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3695-55212-928_1/.txt
# ('evidence value:', -59.8292800177066)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3695-55212-928_1/.txt
# ('evidence value:', -61.502587630523735)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3695-55212-928_1.png', '---98 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3735-55209-621_1/.txt
# ('evidence value:', -72.28860409377405)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3735-55209-621_1/.txt
# ('evidence value:', -61.08293864456096)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3735-55209-621_1.png', '---99 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3735-55209-621_2/.txt
# ('evidence value:', -71.79759251513111)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3735-55209-621_2/.txt
# ('evidence value:', -61.20278023440693)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3735-55209-621_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3735-55209-621_2.png', '---100 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3736-55214-21_1/.txt
# ('evidence value:', -57.014638549859846)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3736-55214-21_1/.txt
# ('evidence value:', -54.828354717447716)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3736-55214-21_1.png', '---101 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3744-55209-705_1/.txt
# ('evidence value:', -63.27424678978168)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3744-55209-705_1/.txt
# ('evidence value:', -61.92846273681419)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3744-55209-705_1.png', '---102 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3745-55234-635_1/.txt
# ('evidence value:', -78.06609362321544)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3745-55234-635_1/.txt
# ('evidence value:', -70.52294836173847)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3745-55234-635_1.png', '---103 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3745-55234-635_2/.txt
# ('evidence value:', -70.04025135287544)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3745-55234-635_2/.txt
# ('evidence value:', -61.390947667721925)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3745-55234-635_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3745-55234-635_2.png', '---104 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3754-55488-639_1/.txt
# ('evidence value:', -58.7799875551788)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3754-55488-639_1/.txt
# ('evidence value:', -60.59496094203317)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3754-55488-639_1.png', '---105 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3758-55506-839_1/.txt
# ('evidence value:', -39.66930553945846)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3758-55506-839_1/.txt
# ('evidence value:', -40.24174175264767)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3758-55506-839_1.png', '---106 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3759-55236-474_1/.txt
# ('evidence value:', -62.75643381674917)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3759-55236-474_1/.txt
# ('evidence value:', -65.13229110071343)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3759-55236-474_1.png', '---107 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3764-55514-591_1/.txt
# ('evidence value:', -58.916416101518294)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3764-55514-591_1/.txt
# ('evidence value:', -60.738467069683)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3764-55514-591_1.png', '---108 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3766-55213-102_1/.txt
# ('evidence value:', -50.85402190610604)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3766-55213-102_1/.txt
# ('evidence value:', -53.83692295803074)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3766-55213-102_1.png', '---109 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3767-55214-925_1/.txt
# ('evidence value:', -52.62622515169787)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3767-55214-925_1/.txt
# ('evidence value:', -53.81243274955166)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/3767-55214-925_1.png', '---110 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/3768-55564-565_1/.txt
# ('evidence value:', -56.191513438037155)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/3768-55564-565_1/.txt
# ...
# ('evidence value:', -72.1792704549781)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9553-57801-476_1/.txt
# ('evidence value:', -76.44640966201712)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9553-57801-476_1.png', '---1223 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9553-57801-843_1/.txt
# ('evidence value:', -44.40203232215103)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9553-57801-843_1/.txt
# ('evidence value:', -44.60970541320926)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9553-57801-843_1.png', '---1224 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9557-58098-549_1/.txt
# ('evidence value:', -57.167135462261484)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9557-58098-549_1/.txt
# ('evidence value:', -58.80863768159167)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9557-58098-549_1.png', '---1225 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9557-58098-621_1/.txt
# ('evidence value:', -89.57205940670907)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9557-58098-621_1/.txt
# ('evidence value:', -84.58753900476502)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9557-58098-621_1.png', '---1226 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9560-57805-941_1/.txt
# ('evidence value:', -83.20687587709044)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9560-57805-941_1/.txt
# ('evidence value:', -74.89723959804657)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9560-57805-941_1.png', '---1227 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9560-57805-944_1/.txt
# ('evidence value:', -79.4627639996757)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9560-57805-944_1/.txt
# ('evidence value:', -73.28200862534028)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9560-57805-944_1.png', '---1228 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9560-57805-970_1/.txt
# ('evidence value:', -71.44395875335775)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9560-57805-970_1/.txt
# ('evidence value:', -68.14901405372576)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9560-57805-970_1.png', '---1229 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9565-58127-345_1/.txt
# ('evidence value:', -88.49383301853779)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9565-58127-345_1/.txt
# ('evidence value:', -85.64584127100402)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9565-58127-345_1.png', '---1230 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9575-57786-183_1/.txt
# ('evidence value:', -68.2749356106704)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9575-57786-183_1/.txt
# ('evidence value:', -67.65469129906107)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9575-57786-183_1.png', '---1231 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9581-57783-22_1/.txt
# ('evidence value:', -46.7916224334325)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9581-57783-22_1/.txt
# ('evidence value:', -48.98712560209211)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9581-57783-22_1.png', '---1232 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-39_1/.txt
# ('evidence value:', -52.3564236736898)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-39_1/.txt
# ('evidence value:', -53.95936420185929)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-39_1.png', '---1233 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-244_1/.txt
# ('evidence value:', -55.778063064550494)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-244_1/.txt
# ('evidence value:', -56.855129421737225)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-244_1.png', '---1234 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-268_1/.txt
# ('evidence value:', -51.49627033504309)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-268_1/.txt
# ('evidence value:', -52.50482287998235)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-268_1.png', '---1235 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-295_1/.txt
# ('evidence value:', -61.683346152816156)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-295_1/.txt
# ('evidence value:', -63.306641378644784)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-295_1.png', '---1236 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-330_1/.txt
# ('evidence value:', -40.06680660562785)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-330_1/.txt
# ('evidence value:', -41.35718390236258)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-330_1.png', '---1237 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9587-57784-436_1/.txt
# ('evidence value:', -64.86261899745938)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9587-57784-436_1/.txt
# ('evidence value:', -66.09383795426004)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9587-57784-436_1.png', '---1238 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9594-58135-159_1/.txt
# ('evidence value:', -69.8656589313961)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9594-58135-159_1/.txt
# ('evidence value:', -77.29158677080737)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9594-58135-159_1.png', '---1239 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9596-57817-183_1/.txt
# ('evidence value:', -92.28892653315876)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9596-57817-183_1/.txt
# ('evidence value:', -86.77233600437715)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9596-57817-183_1.png', '---1240 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9598-58085-16_1/.txt
# ('evidence value:', -58.26505444498942)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9598-58085-16_1/.txt
# ('evidence value:', -63.45098399619399)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9598-58085-16_1.png', '---1241 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9598-58085-227_1/.txt
# ('evidence value:', -40.489893662774854)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9598-58085-227_1/.txt
# ('evidence value:', -40.26916952601841)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9598-58085-227_1.png', '---1242 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9598-58085-227_2/.txt
# ('evidence value:', -67.48638640671518)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9598-58085-227_2/.txt
# ('evidence value:', -62.77541325406001)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9598-58085-227_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9598-58085-227_2.png', '---1243 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9600-58106-176_1/.txt
# ('evidence value:', -97.44419920494974)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9600-58106-176_1/.txt
# ('evidence value:', -82.77459606666697)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9600-58106-176_1.png', '---1244 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9602-58131-602_1/.txt
# ('evidence value:', -55.7305865472559)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9602-58131-602_1/.txt
# ('evidence value:', -60.382033146410464)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9602-58131-602_1.png', '---1245 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9605-58108-998_1/.txt
# ('evidence value:', -55.363220156183026)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9605-58108-998_1/.txt
# ('evidence value:', -56.97587902512339)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9605-58108-998_1.png', '---1246 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9605-58108-998_2/.txt
# ('evidence value:', -56.229713764436795)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9605-58108-998_2/.txt
# ('evidence value:', -55.81354206363311)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9605-58108-998_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9605-58108-998_2.png', '---1247 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9606-58103-253_1/.txt
# ('evidence value:', -49.25659042138502)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9606-58103-253_1/.txt
# ('evidence value:', -50.70190537982859)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9606-58103-253_1.png', '---1248 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9608-58137-465_1/.txt
# ('evidence value:', -81.61339195623435)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9608-58137-465_1/.txt
# ('evidence value:', -85.91518971862186)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9608-58137-465_1.png', '---1249 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9613-57865-895_1/.txt
# ('evidence value:', -65.6899393779939)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9613-57865-895_1/.txt
# ('evidence value:', -73.03035416211281)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9613-57865-895_1.png', '---1250 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9616-58135-159_1/.txt
# ('evidence value:', -122.11341804064347)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9616-58135-159_1/.txt
# ('evidence value:', -125.39376809137183)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9616-58135-159_1.png', '---1251 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9616-58135-475_1/.txt
# ('evidence value:', -57.86076934052082)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9616-58135-475_1/.txt
# ('evidence value:', -61.0649350999645)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9616-58135-475_1.png', '---1252 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9617-58084-504_1/.txt
# ('evidence value:', -105.90386533883031)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9617-58084-504_1/.txt
# ('evidence value:', -114.20139430882045)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9617-58084-504_1.png', '---1253 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9618-58084-989_1/.txt
# ('evidence value:', -52.651600383891164)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9618-58084-989_1/.txt
# ('evidence value:', -53.19229520565299)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9618-58084-989_1.png', '---1254 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9620-57874-373_1/.txt
# ('evidence value:', -66.59415877474567)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9620-57874-373_1/.txt
# ('evidence value:', -63.40929512262247)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9620-57874-373_1.png', '---1255 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9621-58130-112_1/.txt
# ('evidence value:', -47.08782359783436)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9621-58130-112_1/.txt
# ('evidence value:', -48.6089602462556)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9621-58130-112_1.png', '---1256 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9627-58132-475_1/.txt
# ('evidence value:', -45.96186756148118)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9627-58132-475_1/.txt
# ('evidence value:', -47.10145387038944)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9627-58132-475_1.png', '---1257 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9631-58086-155_1/.txt
# ('evidence value:', -89.5624657560024)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9631-58086-155_1/.txt
# ('evidence value:', -74.9163975694221)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9631-58086-155_1.png', '---1258 image-----finished!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9631-58086-155_2/.txt
# ('evidence value:', -62.39973004772492)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9631-58086-155_2/.txt
# ('evidence value:', -51.29531806494789)
# ('----lines:', ['/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9631-58086-155_1.png'])
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9631-58086-155_2.png', '---1259 image-----finished!', '!!!!!!')
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/single/9632-58130-286_1/.txt
# ('evidence value:', -94.9338853645157)
#   analysing data from /data/inspur_disk03/userdir/caoxy/eboss_lya/data/multinest_out/double/9632-58130-286_1/.txt
# ('evidence value:', -102.5757524765149)
# ('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/4/9632-58130-286_1.png', '---1260 image-----finished!')
# ('total time elapse:', 83366.3182258606)

# %%
pwd
# Out:
# u'/data/inspur_disk03/userdir/caoxy/eboss_lya/py/visidual_inspec_module'

# %%
import copy
import pickle
import gzip
from matplotlib import pyplot as plt
import numpy as np
from scipy.signal import medfilt
import h5py

in_dir = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/'
lya_hits = pickle.load(gzip.open(in_dir+'lya_hits_cut.pzip'))

# %%
plate_list
# Out:
# array([10243, 10272, 10274, ...,  9631,  9631,  9632])

# %% [markdown]
# # Note
# this work should use the results from cross talk fie(just run all it procudure in notebook file)

# %%
xx['log_likelihood']
# Out:
# -42.592241708825235

# %%
83366/3600
# Out:
# 23

# %%
import subprocess
import os
import sys
sys.path.append('../')
import utils as ul
import copy
import pickle
import gzip
from matplotlib import pyplot as plt
import numpy as np
from scipy.signal import medfilt
import h5py
from scipy.stats import norm
import time
import pymultinest
import json
import copy

in_dir = '/data/inspur_disk03/userdir/caoxy/eboss_lya/data/'
lya_hits = pickle.load(gzip.open(in_dir+'lya_hits_cut.pzip'))

dir1 = os.getcwd()
os.chdir('/data/inspur_disk03/userdir/caoxy/eboss_lya/data/2')
dir2 = os.getcwd()

plate_list = lya_hits['plate_hits']
fiber_list = lya_hits['fiber_hits']
mjd_list = lya_hits['mjd_hits']
spec_id_list = lya_hits['spec_id']
peak_id_list = lya_hits['peak_id']
peak_wave_list = lya_hits['peak_wave']
peak_sn_list = lya_hits['peak_sn']

# %%
np.where(plate_list==8501)
# Out:
# (array([], dtype=int64),)
